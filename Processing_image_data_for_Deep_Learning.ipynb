# %% [markdown]
# Image data processing - conceptual video: https://youtu.be/Hs5RhjpQVRo

# %% [markdown]
# **Topics:**
#
#
#
# *   Reading an image file and converting it to a numpy array
# *   Resizing an image
# *   RGB to Grayscale conversion

# %%
# getting an image using web get

# !wget 'https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg'
# Out:
# --2026-09-24 10:08:04--  https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg
# Resolving tractive.com (tractive.com)... 13.227.87.64, 13.227.87.80, 13.227.87.77, ...
# Connecting to tractive.com (tractive.com)|13.227.87.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113570 (111K) [image/jpeg]
# Saving to: ‘puppy-care-guide-for-new-parents.jpg.4’
#
# puppy-care-guide-fo 100%[===================>] 110.91K  --.-KB/s    in 0.02s
#
# 2026-09-24 10:08:04 (5.36 MB/s) - ‘puppy-care-guide-for-new-parents.jpg.4’ saved [113570/113570]

# %% [markdown]
# **Libraries that can be used for image processing:**
#
# 1. matplotlib.image
#
# 2. Pillow
#
# 3. OpenCV (cv2)

# %%
# importing the image module from matplotlib library

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module

img = mpimg.imread('/content/marvels-spider-man-3840x2160-11990.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (200, 200)

# %%
print(img)
# Out:
# [[ 19  17  15 ...  14  14  15]
#  [ 21  18  15 ...  14  14  15]
#  [ 24  20  16 ...  14  14  14]
#  ...
#  [ 63  77  84 ... 145 143 133]
#  [ 56  75  78 ... 142 139 129]
#  [ 58  80  78 ... 140 136 124]]

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing the image using Pillow library

# %%
from PIL import Image

# %%
img = Image.open('/content/marvels-spider-man-3840x2160-11990.jpeg')
img_resized = img.resize((200, 200))

# %%
img_resized.save('/content/marvels-spider-man-3840x2160-11990.jpeg')

# %%
# displaying the image from numpy array

img_res = mpimg.imread('/content/marvels-spider-man-3840x2160-11990.jpeg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200)

# %% [markdown]
# **Converting RGB images to Grayscale image using OpenCV**

# %%
# importing OpenCV library
import cv2

# %%
img = cv2.imread('/content/marvels-spider-man-3840x2160-11990.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (200, 200)

# %% [markdown]
# cv2.imshow() will display the image. But this will not be allowed in Google Colab.
#
# **from google.colab.patches import cv2_imshow**

# %%
from google.colab.patches import cv2_imshow

# %%
# displaying the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=200x200>

# %%
# saving the grayscale image
cv2.imwrite('/content/marvels-spider-man-3840x2160-11990.jpeg', grayscale_image)
# Out:
# True
